# %%
import pandas as pd

# %%
comments = pd.read_csv('cms_scrapte.csv')

# %%
comments
# Out:
#                                            name location              rating  \
# 0       \n            Marisa Houshour\n               US         1 star: Bad
# 1          \n            Nancy Snyder\n               US         1 star: Bad
# 2           \n            Jill Riding\n               GB         1 star: Bad
# 3           \n            Ian Griffin\n               GB         1 star: Bad
# 4           \n            nathan falk\n               US         1 star: Bad
# ..                                          ...      ...                 ...
# 838  \n            Marius Thurnhausen\n              NaN      4 stars: Great
# 839       \n            andrew wheats\n              NaN  5 stars: Excellent
# 840         \n            Giles Starz\n              NaN       2 stars: Poor
# 841      \n            Bjarne Heggdal\n              NaN      4 stars: Great
# 842        \n            STEVE YOUNGS\n               GB         1 star: Bad
#
#                           date  \
# ...
